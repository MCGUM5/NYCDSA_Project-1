# %%
# Import relevant modules.
import numpy as np
import pandas as pd
import datetime as date
import matplotlib.pyplot as plt
from sklearn import linear_model
import statsmodels.api as sm

# %%
# Read csv file to 'data' with tabs as delimiter and line 0 as header.
data = pd.read_csv('./SCMS_Delivery_History_Dataset.csv', sep='\t', header=0)

# %%
# View all columns of data for initial inspection.
pd.set_option('display.max_columns', None)
data
# Out:
#           ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0          1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1          3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2          4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3         15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4         16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
# ...      ...          ...             ...       ...      ...            ...
# 10319  86818   103-ZW-T30       FPQ-15197  SO-50020  DN-4307       Zimbabwe
# 10320  86819   104-CI-T30       FPQ-15259  SO-50102  DN-4313  Côte d'Ivoire
# 10321  86821   110-ZM-T30       FPQ-14784  SO-49600  DN-4316         Zambia
# 10322  86822   200-ZW-T30       FPQ-16523  SO-51680  DN-4334       Zimbabwe
# 10323  86823   103-ZW-T30       FPQ-15197  SO-50022  DN-4336       Zimbabwe
#
#       Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 0       PMO - US  Direct Drop              EXW           Air
# 1       PMO - US  Direct Drop              EXW           Air
# 2       PMO - US  Direct Drop              FCA           Air
# 3       PMO - US  Direct Drop              EXW           Air
# 4       PMO - US  Direct Drop              EXW           Air
# ...          ...          ...              ...           ...
# 10319   PMO - US     From RDC   N/A - From RDC         Truck
# 10320   PMO - US     From RDC   N/A - From RDC         Truck
# 10321   PMO - US     From RDC   N/A - From RDC         Truck
# 10322   PMO - US     From RDC   N/A - From RDC         Truck
# 10323   PMO - US     From RDC   N/A - From RDC         Truck
#
#       PQ First Sent to Client Date PO Sent to Vendor Date  \
# 0                   Pre-PQ Process      Date Not Captured
# 1                   Pre-PQ Process      Date Not Captured
# 2                   Pre-PQ Process      Date Not Captured
# 3                   Pre-PQ Process      Date Not Captured
# 4                   Pre-PQ Process      Date Not Captured
# ...                            ...                    ...
# 10319                     10/16/14         N/A - From RDC
# 10320                     10/24/14         N/A - From RDC
# 10321                      8/12/14         N/A - From RDC
# 10322                       7/1/15         N/A - From RDC
# 10323                     10/16/14         N/A - From RDC
#
#       Scheduled Delivery Date Delivered to Client Date Delivery Recorded Date  \
# 0                    2-Jun-06                 2-Jun-06               2-Jun-06
# 1                   14-Nov-06                14-Nov-06              14-Nov-06
# 2                   27-Aug-06                27-Aug-06              27-Aug-06
# 3                    1-Sep-06                 1-Sep-06               1-Sep-06
# 4                   11-Aug-06                11-Aug-06              11-Aug-06
# ...                       ...                      ...                    ...
# 10319               31-Jul-15                15-Jul-15              20-Jul-15
# 10320               31-Jul-15                 6-Aug-15               7-Aug-15
# 10321               31-Aug-15                25-Aug-15               3-Sep-15
# 10322                9-Sep-15                 4-Aug-15              11-Aug-15
# 10323               31-Aug-15                 4-Aug-15              11-Aug-15
#
#       Product Group Sub Classification  \
# 0              HRDT           HIV test
# 1               ARV          Pediatric
# 2              HRDT           HIV test
# 3               ARV              Adult
# 4               ARV              Adult
# ...             ...                ...
# 10319           ARV          Pediatric
# 10320           ARV              Adult
# 10321           ARV              Adult
# 10322           ARV              Adult
# 10323           ARV          Pediatric
#
#                                                   Vendor  \
# 0                            RANBAXY Fine Chemicals LTD.
# 1                               Aurobindo Pharma Limited
# 2                                   Abbott GmbH & Co. KG
# 3      SUN PHARMACEUTICAL INDUSTRIES LTD (RANBAXY LAB...
# 4                               Aurobindo Pharma Limited
# ...                                                  ...
# 10319                                      SCMS from RDC
# 10320                                      SCMS from RDC
# 10321                                      SCMS from RDC
# 10322                                      SCMS from RDC
# 10323                                      SCMS from RDC
#
#                                         Item Description  \
# 0      HIV, Reveal G3 Rapid HIV-1 Antibody Test, 30 T...
# 1      Nevirapine 10mg/ml, oral suspension, Bottle, 2...
# 2         HIV 1/2, Determine Complete HIV Kit, 100 Tests
# 3                     Lamivudine 150mg, tablets, 60 Tabs
# 4                      Stavudine 30mg, capsules, 60 Caps
# ...                                                  ...
# 10319  Lamivudine/Nevirapine/Zidovudine 30/50/60mg, d...
# 10320  Lamivudine/Zidovudine 150/300mg, tablets, 60 Tabs
# 10321  Efavirenz/Lamivudine/Tenofovir Disoproxil Fuma...
# 10322  Lamivudine/Zidovudine 150/300mg, tablets, 60 Tabs
# 10323  Lamivudine/Zidovudine 30/60mg, dispersible tab...
#
#                                       Molecule/Test Type      Brand  \
# 0               HIV, Reveal G3 Rapid HIV-1 Antibody Test     Reveal
# 1                                             Nevirapine    Generic
# 2                    HIV 1/2, Determine Complete HIV Kit  Determine
# 3                                             Lamivudine    Generic
# 4                                              Stavudine    Generic
# ...                                                  ...        ...
# 10319                   Lamivudine/Nevirapine/Zidovudine    Generic
# 10320                              Lamivudine/Zidovudine    Generic
# 10321  Efavirenz/Lamivudine/Tenofovir Disoproxil Fuma...    Generic
# 10322                              Lamivudine/Zidovudine    Generic
# 10323                              Lamivudine/Zidovudine    Generic
#
#               Dosage                        Dosage Form  \
# 0                NaN                           Test kit
# 1            10mg/ml                    Oral suspension
# 2                NaN                           Test kit
# 3              150mg                             Tablet
# 4               30mg                            Capsule
# ...              ...                                ...
# 10319     30/50/60mg  Chewable/dispersible tablet - FDC
# 10320      150/300mg                       Tablet - FDC
# 10321  600/300/300mg                       Tablet - FDC
# 10322      150/300mg                       Tablet - FDC
# 10323        30/60mg  Chewable/dispersible tablet - FDC
#
#        Unit of Measure (Per Pack)  Line Item Quantity  Line Item Value  \
# 0                              30                  19           551.00
# 1                             240                1000          6200.00
# 2                             100                 500         40000.00
# 3                              60               31920        127360.80
# 4                              60               38000        121600.00
# ...                           ...                 ...              ...
# 10319                          60              166571        599655.60
# 10320                          60               21072        137389.44
# 10321                          30              514526       5140114.74
# 10322                          60               17465        113871.80
# 10323                          60               36639         72911.61
#
#        Pack Price  Unit Price              Manufacturing Site  \
# 0           29.00        0.97      Ranbaxy Fine Chemicals LTD
# 1            6.20        0.03       Aurobindo Unit III, India
# 2           80.00        0.80   ABBVIE GmbH & Co.KG Wiesbaden
# 3            3.99        0.07   Ranbaxy, Paonta Shahib, India
# 4            3.20        0.05       Aurobindo Unit III, India
# ...           ...         ...                             ...
# 10319        3.60        0.06      Mylan,  H-12 & H-13, India
# 10320        6.52        0.11    Hetero Unit III Hyderabad IN
# 10321        9.99        0.33   Cipla Ltd A-42 MIDC Mahar. IN
# 10322        6.52        0.11  Mylan (formerly Matrix) Nashik
# 10323        1.99        0.03               Cipla, Goa, India
#
#       First Line Designation          Weight (Kilograms)  \
# 0                        Yes                          13
# 1                        Yes                         358
# 2                        Yes                         171
# 3                        Yes                        1855
# 4                        Yes                        7590
# ...                      ...                         ...
# 10319                     No     See DN-4307 (ID#:83920)
# 10320                     No     See DN-4313 (ID#:83921)
# 10321                     No  Weight Captured Separately
# 10322                    Yes                        1392
# 10323                     No  Weight Captured Separately
#
#                        Freight Cost (USD)  Line Item Insurance (USD)
# 0                                  780.34                        NaN
# 1                                  4521.5                        NaN
# 2                                 1653.78                        NaN
# 3                                16007.06                        NaN
# 4                                45450.08                        NaN
# ...                                   ...                        ...
# 10319             See DN-4307 (ID#:83920)                     705.79
# 10320             See DN-4313 (ID#:83921)                     161.71
# 10321  Freight Included in Commodity Cost                    5284.04
# 10322  Freight Included in Commodity Cost                     134.03
# 10323  Freight Included in Commodity Cost                      85.82
#
# [10324 rows x 33 columns]

# %%
# Convert dates to datetime. 
data['Scheduled Delivery Date'] = pd.to_datetime(
    data['Scheduled Delivery Date'])
data['Delivered to Client Date'] = pd.to_datetime(
    data['Delivered to Client Date'])
data['Delivery Recorded Date'] = pd.to_datetime(
    data['Delivery Recorded Date'])

# %%
# Compare Delivery Recorded vs Delivered dates. 
data['Recorded vs Delivered'] = (data['Delivery Recorded Date'] 
                                 - data['Delivered to Client Date']).dt.days

# %%
# Create a new column for delivery days late (delivered - scheduled)
data['Delivery Days Late'] = (data['Delivered to Client Date'] 
                              - data['Scheduled Delivery Date']).dt.days
data.sort_values('Delivery Days Late', ascending=False)
# Out:
#          ID Project Code            PQ #   PO / SO #  ASN/DN #        Country  \
# 2782  14542   161-ZA-T30        FPQ-5303  SCMS-68980  ASN-9647   South Africa
# 7793  83709   101-CD-T30       FPQ-12033    SO-45020   DN-3268     Congo, DRC
# 7794  83710   101-CD-T30       FPQ-12033    SO-45020   DN-3268     Congo, DRC
# 6880  82595   101-CD-T30       FPQ-12033    SO-45020   DN-3268     Congo, DRC
# 6881  82596   101-CD-T30       FPQ-12033    SO-45020   DN-3268     Congo, DRC
# ...     ...          ...             ...         ...       ...            ...
# 740    7476   116-ZA-T01  Pre-PQ Process  SCMS-33320  ASN-3553   South Africa
# 7289  83100   109-TZ-T30       FPQ-10545    SO-43111   DN-2972       Tanzania
# 430    4190   116-ZA-T01  Pre-PQ Process  SCMS-14050  ASN-1252   South Africa
# 9620  85921   104-CI-T30        FPQ-9749    SO-42370   DN-2970  Côte d'Ivoire
# 7738  83644   104-CI-T30        FPQ-9749    SO-42370   DN-2970  Côte d'Ivoire
#
#      Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 2782   PMO - US  Direct Drop              DDP           Air
# 7793   PMO - US     From RDC   N/A - From RDC           Air
# 7794   PMO - US     From RDC   N/A - From RDC           Air
# 6880   PMO - US     From RDC   N/A - From RDC           Air
# 6881   PMO - US     From RDC   N/A - From RDC           Air
# ...         ...          ...              ...           ...
# 740    PMO - US  Direct Drop              DDP         Truck
# 7289   PMO - US     From RDC   N/A - From RDC         Truck
# 430    PMO - US  Direct Drop              DDP           NaN
# 9620   PMO - US     From RDC   N/A - From RDC         Truck
# 7738   PMO - US     From RDC   N/A - From RDC         Truck
#
#      PQ First Sent to Client Date PO Sent to Vendor Date  \
# 2782                      3/18/10                3/19/10
# 7793                       4/8/13         N/A - From RDC
# 7794                       4/8/13         N/A - From RDC
# 6880                       4/8/13         N/A - From RDC
# 6881                       4/8/13         N/A - From RDC
# ...                           ...                    ...
# 740                Pre-PQ Process      Date Not Captured
# 7289                      8/24/12         N/A - From RDC
# 430                Pre-PQ Process               11/12/07
# 9620                      4/19/12         N/A - From RDC
# 7738                      4/19/12         N/A - From RDC
#
#      Scheduled Delivery Date Delivered to Client Date Delivery Recorded Date  \
# 2782              2010-08-24               2011-03-04             2011-03-04
# 7793              2013-08-27               2014-02-08             2014-03-11
# 7794              2013-08-27               2014-02-08             2014-03-11
# 6880              2013-08-27               2014-02-08             2014-03-11
# 6881              2013-08-27               2014-02-08             2014-03-11
# ...                      ...                      ...                    ...
# 740               2009-05-17               2008-10-09             2008-10-09
# 7289              2013-02-28               2012-02-26             2013-02-26
# 430               2008-01-29               2007-01-24             2008-01-24
# 9620              2013-01-31               2012-01-25             2013-01-25
# 7738              2013-01-31               2012-01-25             2013-01-25
#
#      Product Group Sub Classification                    Vendor  \
# 2782           ARV          Pediatric  Aurobindo Pharma Limited
# 7793           ARV              Adult             SCMS from RDC
# 7794           ARV              Adult             SCMS from RDC
# 6880           ARV              Adult             SCMS from RDC
# 6881           ARV              Adult             SCMS from RDC
# ...            ...                ...                       ...
# 740            ARV              Adult        S. BUYS WHOLESALER
# 7289           ARV          Pediatric             SCMS from RDC
# 430            ARV              Adult   JSI R&T INSTITUTE, INC.
# 9620           ARV              Adult             SCMS from RDC
# 7738           ARV              Adult             SCMS from RDC
#
#                                        Item Description  \
# 2782  Lamivudine 10mg/ml, oral solution w/syringe, B...
# 7793                  Efavirenz 600mg, tablets, 30 Tabs
# 7794    Lopinavir/Ritonavir 200/50mg, tablets, 120 Tabs
# 6880  Lamivudine/Zidovudine 150/300mg, tablets, 60 Tabs
# 6881  Efavirenz/Lamivudine/Tenofovir Disoproxil Fuma...
# ...                                                 ...
# 740         Lamivudine 150mg [Epivir], tablets, 60 Tabs
# 7289           Efavirenz 200mg, scored tablets, 90 Tabs
# 430           Stavudine 30mg [Zerit], capsules, 60 Caps
# 9620  Lamivudine/Nevirapine/Zidovudine 150/200/300mg...
# 7738  Lamivudine/Nevirapine/Zidovudine 150/200/300mg...
#
#                                      Molecule/Test Type    Brand  \
# 2782                                         Lamivudine  Generic
# 7793                                          Efavirenz  Generic
# 7794                                Lopinavir/Ritonavir  Generic
# 6880                              Lamivudine/Zidovudine  Generic
# 6881  Efavirenz/Lamivudine/Tenofovir Disoproxil Fuma...  Generic
# ...                                                 ...      ...
# 740                                          Lamivudine   Epivir
# 7289                                          Efavirenz  Generic
# 430                                           Stavudine    Zerit
# 9620                   Lamivudine/Nevirapine/Zidovudine  Generic
# 7738                   Lamivudine/Nevirapine/Zidovudine  Generic
#
#              Dosage    Dosage Form  Unit of Measure (Per Pack)  \
# 2782        10mg/ml  Oral solution                         240
# 7793          600mg         Tablet                          30
# 7794       200/50mg         Tablet                         120
# 6880      150/300mg   Tablet - FDC                          60
# 6881  600/300/300mg   Tablet - FDC                          30
# ...             ...            ...                         ...
# 740           150mg         Tablet                          60
# 7289          200mg         Tablet                          90
# 430            30mg        Capsule                          60
# 9620  150/300/200mg   Tablet - FDC                          60
# 7738  150/300/200mg   Tablet - FDC                          60
#
#       Line Item Quantity  Line Item Value  Pack Price  Unit Price  \
# 2782                6395         19185.00        3.00        0.01
# 7793                 238           792.54        3.33        0.11
# 7794                 378          8232.84       21.78        0.18
# 6880               10590         74130.00        7.00        0.12
# 6881                7404         77890.08       10.52        0.35
# ...                  ...              ...         ...         ...
# 740                 1200          5772.00        4.81        0.08
# 7289                5765         42084.50        7.30        0.08
# 430                  800          4792.00        5.99        0.10
# 9620               40455        389177.10        9.62        0.16
# 7738                9577         92130.74        9.62        0.16
#
#                         Manufacturing Site First Line Designation  \
# 2782             Aurobindo Unit III, India                    Yes
# 7793            Strides, Bangalore, India.                     No
# 7794        Mylan (formerly Matrix) Nashik                     No
# 6880          Hetero Unit III Hyderabad IN                    Yes
# 6881          Hetero Unit III Hyderabad IN                     No
# ...                                    ...                    ...
# 740   GSK Cape Town Factory (South Africa)                     No
# 7289            Strides, Bangalore, India.                    Yes
# 430                     BMS Meymac, France                    Yes
# 9620          Hetero Unit III Hyderabad IN                     No
# 7738             Aurobindo Unit III, India                    Yes
#
#               Weight (Kilograms)                  Freight Cost (USD)  \
# 2782  Weight Captured Separately  Freight Included in Commodity Cost
# 7793     See DN-3268 (ID#:82595)             See DN-3268 (ID#:82595)
# 7794     See DN-3268 (ID#:82595)             See DN-3268 (ID#:82595)
# 6880                        5426                            20499.33
# 6881     See DN-3268 (ID#:82595)             See DN-3268 (ID#:82595)
# ...                          ...                                 ...
# 740   Weight Captured Separately  Freight Included in Commodity Cost
# 7289                         350                                2266
# 430   Weight Captured Separately  Freight Included in Commodity Cost
# 9620     See DN-2970 (ID#:83644)             See DN-2970 (ID#:83644)
# 7738                        6889                            24138.35
#
#       Line Item Insurance (USD)  Recorded vs Delivered  Delivery Days Late
# 2782                      41.36                      0                 192
# 7793                       0.98                     31                 165
# 7794                      10.18                     31                 165
# 6880                      91.70                     31                 165
# 6881                      96.35                     31                 165
# ...                         ...                    ...                 ...
# 740                       11.31                      0                -220
# 7289                      59.00                    366                -368
# 430                        7.67                    365                -370
# 9620                     545.63                    366                -372
# 7738                     129.17                    366                -372
#
# [10324 rows x 35 columns]

# %%
# Remove columns that we know are unrelated to delivery delays. 
data = data.drop('Project Code', 1)
data = data.drop('PQ #', 1)
data = data.drop('PO / SO #', 1)
data = data.drop('ASN/DN #', 1)
data = data.drop('PQ First Sent to Client Date', 1)
data = data.drop('PO Sent to Vendor Date', 1)
data = data.drop('Line Item Insurance (USD)', 1)
data = data.drop('Item Description', 1)
data = data.drop('First Line Designation', 1)

# %%
# Inspect data by using frequency distributions
data['Country'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Group Countries with low frequency as 'Other'.
data['Country'] = data['Country'].replace([
    'Guinea', 'Belize', 'Kyrgyzstan', 'Burkina Faso', 
    'Kazakhstan', 'Togo', 'Senegal', 'Afghanistan', 'Lesotho', 
    'Sierra Leone', 'Liberia', 'Angola',  'Lebanon', 
    'Libya', 'Benin', 'Malawi', 'Guatemala', 'Pakistan', 
    'Mali', 'Swaziland', 'Sudan', 'Dominican Republic', 
    'Ghana', 'Botswana', 'Cameroon', 'Namibia', 'Burundi', 'Kenya'], 'Other')

# %%
# Inspect data by using frequency distributions
data['Managed By'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Remove 'Managed By' from data since it is almost all PMO-US.
data = data.drop('Managed By', 1)

# %%
# Inspect data by using frequency distributions
data['Fulfill Via'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Inspect data by using frequency distributions
data['Vendor INCO Term'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Group values with low frequency as 'Other'
data['Vendor INCO Term'] = data['Vendor INCO Term'].replace(['FCA', 'CIP', 'DDU', 'DAP', 'CIF'], 'Other')

# %%
# Inspect data by using frequency distributions
data['Shipment Mode'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Inspect data by using frequency distributions
data['Product Group'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data['Product Group'] = data[
    'Product Group'].replace(['ANTM', 'ACT', 'MRDT'], 'Other')

# %%
# Inspect data by using frequency distributions
data['Sub Classification'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# We can drop Sub Class as it directly relates to Product Group
data = data.drop('Sub Classification', 1)

# %%
# Inspect data by using frequency distributions
data['Vendor'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Inspect data by using frequency distributions
data['Molecule/Test Type'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Drop Test Type since it is too unique. 
data = data.drop('Molecule/Test Type', 1)

# %%
# Inspect data by using frequency distributions
data['Brand'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Create a new column for generic vs non-generic brands. 
data['Generic Brand'] = data[data['Brand'] == 'Generic']['Brand']
data['Generic Brand'] = data['Generic Brand'].replace(np.nan, 'Non-generic', regex =True)
# Remove original Brands column.
data = data.drop('Brand', 1)

# %%
# Inspect data by using frequency distributions
data['Dosage'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Drop dosage since it does not relate to shipping. 
data = data.drop('Dosage', 1)

# %%
# Inspect data by using frequency distributions
data['Dosage Form'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data['Dosage Form'] = data['Dosage Form'].replace(['Tablet - blister', 'Tablet - FDC + blister', 
                 'Tablet - FDC + co-blister', 'Chewable/dispersible tablet', 
                 'Chewable/dispersible tablet - FDC', 'Tablet - FDC'], 'Tablet')
data['Dosage Form'] = data['Dosage Form'].replace(['Oral powder', 'Powder for oral solution', 
                                                  'Oral suspension'], 'Oral solution')
data['Dosage Form'] = data['Dosage Form'].replace(['Delayed-release capsules - blister', 
                                                   'Delayed-release capsules'], 'Capsule')
data['Dosage Form'] = data['Dosage Form'].replace(['Injection', 'Test kit - Ancillary'], 'Test kit')

# %%
# Inspect data by using frequency distributions
data['Unit of Measure (Per Pack)'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# We do not care about how many units are in each pack
 # this is because pack is subjective. 
data = data.drop('Unit of Measure (Per Pack)', 1)

# %%
# Inspect data by using frequency distributions
data['Line Item Quantity'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Inspect data by using frequency distributions
data['Line Item Value'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Inspect data by using frequency distributions
data['Pack Price'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Inspect data by using frequency distributions
data['Unit Price'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# We do not care about how much each unit costs since we do not know
    # the number of units shipped. 
data = data.drop('Unit Price', 1)

# %%
# Inspect data by using frequency distributions
data['Manufacturing Site'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Drop the emtpy values now that we have cleaned up the columns. 
# Doing this now since we will introduce more NaN below.
data = data.dropna()
data

# %%
# Inspect data by using frequency distributions
data['Weight (Kilograms)'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# apply to numeric so that the string values show as NaN.
data['Weight (Kilograms)'] = data[
    'Weight (Kilograms)'].apply(pd.to_numeric, errors='coerce')

# %%
# Inspect data by using frequency distributions
data['Freight Cost (USD)'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data['Freight Cost (USD)'] = data[
    'Freight Cost (USD)'].apply(pd.to_numeric, errors='coerce')

# %%
# Inspect data by using frequency distributions
data['Delivery Days Late'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data
# Out:
#           ID        Country  Fulfill Via Vendor INCO Term Shipment Mode  \
# 0          1  Côte d'Ivoire  Direct Drop              EXW           Air
# 1          3        Vietnam  Direct Drop              EXW           Air
# 2          4  Côte d'Ivoire  Direct Drop            Other           Air
# 3         15        Vietnam  Direct Drop              EXW           Air
# 4         16        Vietnam  Direct Drop              EXW           Air
# ...      ...            ...          ...              ...           ...
# 10319  86818       Zimbabwe     From RDC   N/A - From RDC         Truck
# 10320  86819  Côte d'Ivoire     From RDC   N/A - From RDC         Truck
# 10321  86821         Zambia     From RDC   N/A - From RDC         Truck
# 10322  86822       Zimbabwe     From RDC   N/A - From RDC         Truck
# 10323  86823       Zimbabwe     From RDC   N/A - From RDC         Truck
#
#       Scheduled Delivery Date Delivered to Client Date Delivery Recorded Date  \
# 0                  2006-06-02               2006-06-02             2006-06-02
# 1                  2006-11-14               2006-11-14             2006-11-14
# 2                  2006-08-27               2006-08-27             2006-08-27
# 3                  2006-09-01               2006-09-01             2006-09-01
# 4                  2006-08-11               2006-08-11             2006-08-11
# ...                       ...                      ...                    ...
# 10319              2015-07-31               2015-07-15             2015-07-20
# 10320              2015-07-31               2015-08-06             2015-08-07
# 10321              2015-08-31               2015-08-25             2015-09-03
# 10322              2015-09-09               2015-08-04             2015-08-11
# 10323              2015-08-31               2015-08-04             2015-08-11
#
#       Product Group                                             Vendor  \
# 0              HRDT                        RANBAXY Fine Chemicals LTD.
# 1               ARV                           Aurobindo Pharma Limited
# 2              HRDT                               Abbott GmbH & Co. KG
# 3               ARV  SUN PHARMACEUTICAL INDUSTRIES LTD (RANBAXY LAB...
# 4               ARV                           Aurobindo Pharma Limited
# ...             ...                                                ...
# 10319           ARV                                      SCMS from RDC
# 10320           ARV                                      SCMS from RDC
# 10321           ARV                                      SCMS from RDC
# 10322           ARV                                      SCMS from RDC
# 10323           ARV                                      SCMS from RDC
#
#          Dosage Form  Line Item Quantity  Line Item Value  Pack Price  \
# 0           Test kit                  19           551.00       29.00
# 1      Oral solution                1000          6200.00        6.20
# 2           Test kit                 500         40000.00       80.00
# 3             Tablet               31920        127360.80        3.99
# 4            Capsule               38000        121600.00        3.20
# ...              ...                 ...              ...         ...
# 10319         Tablet              166571        599655.60        3.60
# 10320         Tablet               21072        137389.44        6.52
# 10321         Tablet              514526       5140114.74        9.99
# 10322         Tablet               17465        113871.80        6.52
# 10323         Tablet               36639         72911.61        1.99
#
#                    Manufacturing Site  Weight (Kilograms)  Freight Cost (USD)  \
# 0          Ranbaxy Fine Chemicals LTD                13.0              780.34
# 1           Aurobindo Unit III, India               358.0             4521.50
# 2       ABBVIE GmbH & Co.KG Wiesbaden               171.0             1653.78
# 3       Ranbaxy, Paonta Shahib, India              1855.0            16007.06
# 4           Aurobindo Unit III, India              7590.0            45450.08
# ...                               ...                 ...                 ...
# 10319      Mylan,  H-12 & H-13, India                 NaN                 NaN
# 10320    Hetero Unit III Hyderabad IN                 NaN                 NaN
# 10321   Cipla Ltd A-42 MIDC Mahar. IN                 NaN                 NaN
# 10322  Mylan (formerly Matrix) Nashik              1392.0                 NaN
# 10323               Cipla, Goa, India                 NaN                 NaN
#
#        Recorded vs Delivered  Delivery Days Late Generic Brand
# 0                          0                   0   Non-generic
# 1                          0                   0       Generic
# 2                          0                   0   Non-generic
# 3                          0                   0       Generic
# 4                          0                   0       Generic
# ...                      ...                 ...           ...
# 10319                      5                 -16       Generic
# 10320                      1                   6       Generic
# 10321                      9                  -6       Generic
# 10322                      7                 -36       Generic
# 10323                      7                 -27       Generic
#
# [9964 rows x 20 columns]

# %%
# let's remove values with not enough data

# %%
# Let's remove outliers

# %%
# let's assign the data to X and Y
X1 = data[['Country', 'Fulfill Via', 'Vendor INCO Term', 'Shipment Mode', 
         'Vendor', 'Dosage Form', 'Manufacturing Site', 'Product Group', 'Generic Brand']]
X2 = data[['Line Item Quantity', 'Line Item Value', 'Pack Price']]
Y = data['Delivery Days Late']

# %%
# Set dummy variables
X1 = pd.get_dummies(data=X1, drop_first=True)

# %%
# Combine the string data with numeric data
X = pd.concat([X1, X2], axis=1)

# %%
# Split the data for testing
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size = 0.2, random_state = 42)

# %%
# Time for multiple linear regression!
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
print('Intercept: \n', regr.intercept_)
print('Coefficents: \n', regr.coef_)
# Out:
# Intercept:
#  20.73670768954044
# Coefficents:
#  [-1.83704193e+01 -1.73572972e+01 -3.14179511e+01 -1.65152965e+01
#  -1.37693430e+01 -1.54849940e+01 -1.69554335e+01 -1.98426237e+01
#   4.97309733e+00 -1.45893113e+01 -1.88407948e+01 -1.91267043e+01
#  -2.00701058e+01 -1.84578905e+01 -2.36790459e+01 -4.13684199e+00
#   6.00608464e+00 -4.13684292e+00  6.06139211e+00 -1.01784659e+01
#  -3.35133589e+00  5.08239122e+00  1.83426607e-11 -1.00975518e+01
#  -1.97492781e+01  1.37084389e+00 -1.27439561e+01 -3.12053276e+01
#  -6.97188261e+00 -2.58124973e+01 -9.84848826e+00 -3.27096106e+01
#  -1.72308562e+01 -9.60794023e+00 -1.41587051e+01 -1.78190739e+01
#  -2.97672741e+01  3.19138396e+00  3.31502478e+01 -5.60973490e-12
#  -3.67280287e+01 -1.81783161e+01 -7.66243337e+00 -1.61682528e+01
#  -3.90929645e+00  7.38890627e-02 -6.28775691e+00 -1.10238977e+01
#  -5.70370983e+00 -2.32436402e-01  5.66588106e+00 -2.47917286e+01
#   1.98507099e+01 -1.93977035e+01 -6.47970944e+00 -1.74288074e+01
#  -1.75751200e+01 -1.52543494e+01 -1.46488019e+01 -1.49123545e+01
#   1.98955904e+00  2.89471479e-01 -1.42154822e+01 -2.91499072e+00
#  -2.23136052e+01 -1.51188871e+01 -4.38838301e+00 -2.25153024e+01
#   4.76063633e-13 -2.57899147e-01 -1.59843791e+01 -3.27486694e+01
#  -2.30828179e+01  5.35646894e+00 -1.11010152e+01 -2.84217094e-14
#  -2.27373675e-13 -2.82471330e+01 -5.34202924e+01 -4.13684292e+00
#  -5.68434189e-14  1.59578701e+00 -3.74107195e+00 -1.68498930e+01
#  -2.00866275e+01 -1.83613184e+00 -1.32360225e+01 -1.47372916e+01
#  -1.42157053e+01 -1.31520269e+01 -1.89090882e+01 -3.25069161e+01
#  -1.83034074e+00 -2.18676863e+00 -3.34393164e+00 -5.02441317e+01
#  -2.34501604e+00  3.25910358e+01  2.09203837e+00  2.55165642e+00
#   2.01351637e+01  1.76146929e+01  6.16839303e+00  1.37084389e+00
#   1.65180553e+01  7.80482684e+00  4.67827683e+00  4.09184859e+00
#  -6.25514577e+01 -1.67618805e-01 -4.00650713e+01  1.64313008e-14
#   1.62223800e+01 -2.43256281e+01  2.48790119e+01 -8.20454281e+00
#   1.59708385e+01 -1.64720076e+01  5.60270422e+00  5.61522153e+00
#  -3.37809925e-02  7.38890627e-02  1.06239860e+01 -5.55776149e+01
#   1.06581410e-14 -1.85068208e+01  8.53195964e+00 -1.02794226e+01
#   1.13867184e+01  2.59850907e+01  2.18048646e+00  2.91876057e+01
#   2.22806583e+01 -4.16783619e+01  2.45365739e+00  3.73392634e+00
#  -2.32436402e-01  1.82227661e+01 -2.84217094e-14  1.71651140e+01
#   1.77807445e+01 -1.62763365e+01 -3.90929645e+00  6.59161518e+00
#   1.59578701e+00  6.85162024e+00  6.13389162e+00 -4.79096567e+01
#   6.14845054e+00  5.61893195e+00  7.25347725e+00 -1.50526763e+01
#   2.89471479e-01  0.00000000e+00 -1.98290188e+01 -1.83084896e+01
#   2.66453526e-15 -2.03985946e+01 -2.97654830e+01 -9.30656881e-01
#   1.03671198e-01  1.28608428e-01  1.92534406e+01 -2.06349421e+01
#  -2.31658202e+01  0.00000000e+00 -5.38308459e+00  1.37596851e+00
#  -3.22266568e+00  1.48901284e+01  1.36988742e+01  0.00000000e+00
#  -1.76224226e+01  1.85282636e+01  1.71253675e+01  0.00000000e+00
#  -1.85182873e+01  4.59395233e-01  1.74302409e+01 -1.16996556e+00
#   1.76657316e+01 -2.16630875e+01  3.19138396e+00  3.92317020e+01
#   3.71200990e+01 -3.38699494e-01 -4.88147915e-05  3.47177747e-06
#   1.81001499e-02]

# %%
Y_prediction = regr.predict(X_test)
Y_prediction
# Out:
# array([-4.45029367,  1.97023675,  0.74688011, ..., -3.46299328,
#         0.21588485, -3.5371742 ])

# %%
# importing r^2 score module
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
# Predicting the accuracy score
score = r2_score(Y_test, Y_prediction)
print('r2 score is', score)
print('mean_sqrd_error is==', mean_squared_error(Y_test, Y_prediction))
print('root_mean_squared error is==', np.sqrt(mean_squared_error(Y_test, Y_prediction)))
# Out:
# r2 score is 0.09519161244893859
# mean_sqrd_error is== 624.1589417377786
# root_mean_squared error is== 24.983173171912703

# %%
# This is a very bad r2 score.
# Let's remove outliers.
# Let's different variables and combinations.

# %%
data_to_strip = data[['Weight (Kilograms)', 'Freight Cost (USD)', 'Delivery Days Late']]
data_stripped = data_to_strip.dropna()
data_stripped
# Out:
#        Weight (Kilograms)  Freight Cost (USD)  Delivery Days Late
# 0                    13.0              780.34                   0
# 1                   358.0             4521.50                   0
# 2                   171.0             1653.78                   0
# 3                  1855.0            16007.06                   0
# 4                  7590.0            45450.08                   0
# ...                   ...                 ...                 ...
# 10305             39688.0            28277.42                  11
# 10306              1504.0             1653.90                  17
# 10310              2253.0             3785.72                 -26
# 10315             15198.0            26180.00                 -46
# 10316              1547.0             3410.00                 -18
#
# [5964 rows x 3 columns]

# %%
X3 = data_stripped[['Weight (Kilograms)', 'Freight Cost (USD)']]
Y2 = data_stripped['Delivery Days Late']

# %%
X3_train, X3_test, Y2_train, Y2_test = train_test_split(
    X3, Y2, test_size = 0.2, random_state = 42)

# %%
regr2 = linear_model.LinearRegression()
regr2.fit(X3_train, Y2_train)
# Out:
# LinearRegression()

# %%
print('Intercept: \n', regr2.intercept_)
print('Coefficents: \n', regr2.coef_)
# Out:
# Intercept:
#  -3.666359915667166
# Coefficents:
#  [-3.31491185e-05 -4.25671075e-05]

# %%
Y2_prediction = regr2.predict(X3_test)
Y2_prediction
# Out:
# array([-4.30099555, -4.5843447 , -3.80412195, ..., -3.85142701,
#        -4.63536232, -3.74101624])

# %%
score2 = r2_score(Y2_test, Y2_prediction)
print('r2 score is', score2)
print('mean_sqrd_error is==', mean_squared_error(Y2_test, Y2_prediction))
print('root_mean_squared error is==', np.sqrt(mean_squared_error(Y2_test, Y2_prediction)))
# Out:
# r2 score is 0.0024273874870934797
# mean_sqrd_error is== 447.939205594474
# root_mean_squared error is== 21.164574306951558
